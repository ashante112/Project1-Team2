# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
output_data = "Resources/Project 1 Data.csv"
data_df = pd.read_csv(output_data)
data_df
# Out:
#       SCL_UNITID                   SCL_NAME  SPORT_CODE  \
# 0         100654     Alabama A&M University           1
# 1         100654     Alabama A&M University           2
# 2         100654     Alabama A&M University           4
# 3         100654     Alabama A&M University           6
# 4         100654     Alabama A&M University          13
# ...          ...                        ...         ...
# 6012      486840  Kennesaw State University          28
# 6013      486840  Kennesaw State University          30
# 6014      486840  Kennesaw State University          33
# 6015      486840  Kennesaw State University          34
# 6016      486840  Kennesaw State University          35
#
#                         SPORT_NAME SCL_HBCU SCL_PRIVATE  APR_RATE_2019_1000  \
# 0                         Baseball        Y           N               947.0
# 1                 Men's Basketball        Y           N               867.0
# 2                         Football        Y           N               900.0
# 3                       Men's Golf        Y           N               962.0
# 4                     Men's Tennis        Y           N              1000.0
# ...                            ...      ...         ...                 ...
# 6012              Women's Softball        N           N              1000.0
# 6013                Women's Soccer        N           N              1000.0
# 6014                Women's Tennis        N           N              1000.0
# 6015  Women's Track, Cross Country        N           N              1000.0
# 6016            Women's Volleyball        N           N              1000.0
#
#       ELIG_RATE_2019  RET_RATE_2019  NUM_OF_ATHLETES_2019  ...  RET_RATE_2006  \
# 0           0.947368       0.945946                  19.0  ...       0.948718
# 1           0.875000       0.857143                  13.0  ...       0.846154
# 2           0.889655       0.909722                  78.0  ...       0.962963
# 3           1.000000       0.923077                   7.0  ...       0.888889
# 4           1.000000       1.000000                   7.0  ...       0.888889
# ...              ...            ...                   ...  ...            ...
# 6012        1.000000       1.000000                  24.0  ...       0.916667
# 6013        1.000000       1.000000                  29.0  ...       0.973684
# 6014        1.000000       1.000000                   9.0  ...       0.933333
# 6015        1.000000       1.000000                  32.0  ...       0.941176
# 6016        1.000000       1.000000                  13.0  ...            NaN
#
#       NUM_OF_ATHLETES_2006  APR_RATE_2005_1000  ELIG_RATE_2005  RET_RATE_2005  \
# 0                     21.0               917.0        0.880952       0.952381
# 1                     13.0               909.0        0.909091       0.909091
# 2                     70.0               921.0        0.875862       0.965517
# 3                      5.0               929.0        0.857143       1.000000
# 4                      5.0              1000.0        1.000000       1.000000
# ...                    ...                 ...             ...            ...
# 6012                  18.0                 NaN             NaN            NaN
# 6013                  19.0                 NaN             NaN            NaN
# 6014                   8.0                 NaN             NaN            NaN
# 6015                  17.0                 NaN             NaN            NaN
# 6016                   NaN                 NaN             NaN            NaN
#
#       NUM_OF_ATHLETES_2005  APR_RATE_2004_1000  ELIG_RATE_2004  RET_RATE_2004  \
# 0                     21.0               975.0         0.97500       0.975000
# 1                     11.0               950.0         0.95000       0.950000
# 2                     74.0               871.0         0.86014       0.881119
# 3                      7.0                 NaN             NaN            NaN
# 4                      4.0               958.0         1.00000       0.916667
# ...                    ...                 ...             ...            ...
# 6012                   NaN                 NaN             NaN            NaN
# 6013                   NaN                 NaN             NaN            NaN
# 6014                   NaN                 NaN             NaN            NaN
# 6015                   NaN                 NaN             NaN            NaN
# 6016                   NaN                 NaN             NaN            NaN
#
#       NUM_OF_ATHLETES_2004
# 0                     20.0
# 1                     10.0
# 2                     74.0
# 3                      NaN
# 4                      6.0
# ...                    ...
# 6012                   NaN
# 6013                   NaN
# 6014                   NaN
# 6015                   NaN
# 6016                   NaN
#
# [6017 rows x 70 columns]

# %%
data_df["SCL_NAME"].nunique()
# Out:
# 385

# %%
# APR scores over time

# %%
# Gender comparison of APR scores

# %%
# Comparison between sports

# %%
# Drop APR score

# %%
# Geographical representation of schools by APR score
